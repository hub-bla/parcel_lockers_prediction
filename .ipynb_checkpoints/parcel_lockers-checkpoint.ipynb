# %% [markdown]
# ## Introduction
#
# The project focuses on analyzing the distribution of parcel lockers in Poznań, divided into housing estates.
# The inspiration for this analysis was the Wilson Project by Allegro.
#
#
# ### Obtained data
# #### Parcel lockers
# Data about location of parcel lockers was scraped from [inpost website](https://inpost.pl/znajdz-paczkomat) using Selenium in Python. The code for that is located in the `scraper.py`.
#
# Scraped data is located in `lockers_data.csv` file and consist following columns:
#  - `id` - unique id of parcel locker
#  - `address` - addres of the parcel locker (street, post code, city)
#  - `description` - descriptive explanation of the parcel locker location
#  -  `longitude`
#  -  `latitude`
#
# #### Area of housing estates
#
# The data was obtained from [sip.poznan.pl](https://sip.poznan.pl/sip/dzielnice/get_dzielnice) in geojson format.
#
# #### Number of resident
#
# The data was obtained from [badam.poznan.pl](https://badam.poznan.pl/wp-content/uploads/2020/03/Liczba-mieszka%C5%84c%C3%B3w-wg-jednostek-pomocniczych-w-2019-r..pdf) in pdf format and preprocessed in the `residents_pdf_to_csv.ipynb` file.

# %%
import pandas as pd
import geopandas
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# #### Prepare data

# %% [markdown]
# ##### Get residents

# %%
residents = pd.read_csv('residents.csv')
residents.head()
# Out:
#                     Nazwa osiedla  Powierzchnia w km2  Liczba mieszkańców*  \
# 0  Antoninek-Zieliniec-Kobylepole               20.54                 9837
# 1                        Chartowo                4.49                22110
# 2                Fabianowo-Kotowo                7.10                 1771
# 3                          Główna                6.82                 4507
# 4                        Głuszyna               14.43                 3875
#
#    Gęstość zaludnienia
# 0               478.92
# 1              4924.28
# 2               249.44
# 3               660.85
# 4               268.54

# %% [markdown]
# ##### Get estates borders and parcel lockers location

# %%
estates = geopandas.read_file('estates.geojson')
parcel_lockers = pd.read_csv('lockers_data.csv')

# %%
parcel_lockers = geopandas.GeoDataFrame(
    parcel_lockers, geometry=geopandas.points_from_xy(parcel_lockers['longitude'], parcel_lockers['latitude']), crs='EPSG:4326'
)

# %%
parcel_lockers
# Out:
#             id                                     address  \
# 0       POZ07B                 Głogowska 268 60-104 Poznań
# 1       POZ77M                 Głogowska 267 60-104 Poznań
# 2      POZ229M                   Mrągowska 4 60-161 Poznań
# 3       POZ51A                      Kacza 15 60-106 Poznań
# 4      POZ137M                  Fabianowo 87 60-005 Poznań
# ...        ...                                         ...
# 1273    KAL29M              Sulisławicka 104 62-800 Kalisz
# 1274  KAL03APP                Wrocławska 203 62-800 Kalisz
# 1275    DAI01N                       Kolska 5 62-660 Dąbie
# 1276    WDK01M  Wola Droszewska 45B 62-872 Wola Droszewska
# 1277    KAL33M          Wrocławska 292-298A. 62-800 Kalisz
#
#                                      description  longitude  latitude  \
# 0                       Stacja paliw AMIC ENERGY   16.86899  52.37494
# 1                     Przy wypożyczalni Ramirent   16.86890  52.37391
# 2          Na parkingu Parku Handlowego KOPERNIK   16.86580  52.38095
# 3     Na terenie myjni samoobsługowej Banieczka.   16.86187  52.38195
# 4                 Na parkingu przy sklepie Żabka   16.85529  52.36583
# ...                                          ...        ...       ...
# 1273                       teren OSP Sulisławice   18.06935  51.71492
# 1274                           Obok sklepu Odido   18.02043  51.72501
# 1275          Przy sklepie spożywczym Społem PSS   18.81912  52.08702
# 1276                                 Market Dino   18.10511  51.63031
# 1277                                 Market Dino   18.00233  51.71651
#
#                        geometry
# 0     POINT (16.86899 52.37494)
# 1     POINT (16.86890 52.37391)
# 2     POINT (16.86580 52.38095)
# 3     POINT (16.86187 52.38195)
# 4     POINT (16.85529 52.36583)
# ...                         ...
# 1273  POINT (18.06935 51.71492)
# 1274  POINT (18.02043 51.72501)
# 1275  POINT (18.81912 52.08702)
# 1276  POINT (18.10511 51.63031)
# 1277  POINT (18.00233 51.71651)
#
# [1278 rows x 6 columns]

# %%
parcel_lockers_in_poz = parcel_lockers[parcel_lockers['id'].str.contains('POZ')]['geometry']

# %%
population_density_grid = geopandas.read_file('population_density_500m.geojson')

# %%
# population_density_grid.to_crs()
population_density_grid = population_density_grid.to_crs('EPSG:4326')

# %%
population_density_grid.plot(column='LICZBA_MIESZKANCOW', legend=True, cmap='inferno')
# Out:
# <Axes: >

# %%
grid['num_lockers'][grid['num_lockers'] > 0].sum(), estates['num_lockers'].sum()
# Out:
# (404, 403)

# %%
# Out:
# <Axes: >

# %%
population_density_grid
# Out:
#                                                      id   ID  \
# 0     mieszkancy500_sql.fid--65faa420_18f66ebac5e_-53da    3
# 1     mieszkancy500_sql.fid--65faa420_18f66ebac5e_-53d9    4
# 2     mieszkancy500_sql.fid--65faa420_18f66ebac5e_-53d8    5
# 3     mieszkancy500_sql.fid--65faa420_18f66ebac5e_-53d7    6
# 4     mieszkancy500_sql.fid--65faa420_18f66ebac5e_-53d6    7
# ...                                                 ...  ...
# 1183  mieszkancy500_sql.fid--65faa420_18f66ebac5e_-4f3b  945
# 1184  mieszkancy500_sql.fid--65faa420_18f66ebac5e_-4f3a  946
# 1185  mieszkancy500_sql.fid--65faa420_18f66ebac5e_-4f39  947
# 1186  mieszkancy500_sql.fid--65faa420_18f66ebac5e_-4f38  948
# 1187  mieszkancy500_sql.fid--65faa420_18f66ebac5e_-4f37  949
#
#       LICZBA_MIESZKANCOW PRZEDZIAL  \
# 0                      0         0
# 1                      0         0
# 2                      0         0
# 3                     10         1
# 4                      0         0
# ...                  ...       ...
# 1183                   0         0
# 1184                   0         0
# 1185                  10         1
# 1186                  11         1
# 1187                  36         1
#
#                                                geometry  num_lockers
# 0     POLYGON ((16.98127 52.29311, 16.98860 52.29317...            0
# 1     POLYGON ((16.98860 52.29317, 16.99593 52.29323...            0
# 2     POLYGON ((16.99593 52.29323, 17.00326 52.29329...            0
# 3     POLYGON ((16.97384 52.29754, 16.98117 52.29760...            0
# 4     POLYGON ((16.98117 52.29760, 16.98850 52.29766...            0
# ...                                                 ...          ...
# 1183  POLYGON ((16.77898 52.45297, 16.78634 52.45305...            0
# 1184  POLYGON ((16.78634 52.45305, 16.79369 52.45312...            0
# 1185  POLYGON ((16.79369 52.45312, 16.80104 52.45320...            0
# 1186  POLYGON ((16.80104 52.45320, 16.80840 52.45327...            0
# 1187  POLYGON ((16.80840 52.45327, 16.81575 52.45335...            0
#
# [1188 rows x 6 columns]

# %%
#correct spellings in residents
# estates and residents are sorted alphabetically by estate names
residents['Nazwa osiedla'] = estates['name']

# %%
# matrix where each row represents which lockers are in the estate
# shape: num_estates x num_lockers
lockers_in_estates = estates['geometry'].apply(lambda estate: estate.contains(parcel_lockers['geometry']))

# count number of lockers in particular estate
estates['num_lockers'] = np.array([parcel_lockers[lockers_in_estates.iloc[i]].shape[0] for i in range(estates.shape[0])])

estates.head()
# Out:
#      id                            name  \
# 0  1260  Antoninek-Zieliniec-Kobylepole
# 1  1261                        Chartowo
# 2  1242                Fabianowo-Kotowo
# 3  1262                          Główna
# 4  1263                        Głuszyna
#
#                                             geometry  num_lockers
# 0  POLYGON ((17.01099 52.42902, 17.01158 52.42797...            7
# 1  POLYGON ((16.97736 52.40177, 16.97892 52.40165...           13
# 2  POLYGON ((16.85011 52.37851, 16.85018 52.37849...            4
# 3  POLYGON ((17.02008 52.44922, 17.02043 52.44810...            5
# 4  POLYGON ((16.94412 52.34228, 16.94418 52.34227...            1

# %%
import folium
CENTER = (52.4, 16.9)

map = folium.Map(location=CENTER,zoom_start=11, tiles="CartoDB positron")

show_lockers_locations = False
# put estates on map
for id, r in estates.iterrows():
    if show_lockers_locations:
        points_lat = parcel_lockers[lockers_in_estates.iloc[id]]['latitude']
        points_lng = parcel_lockers[lockers_in_estates.iloc[id]]['longitude']
        for point in zip(points_lat,points_lng):
            folium.Marker(point).add_to(map)
        
    sim_geo = geopandas.GeoSeries(r["geometry"]).simplify(tolerance=0.00001)
    geo_j = sim_geo.to_json()
    # print(geo_j)
    geo_j = folium.GeoJson(data=geo_j, style_function=lambda x: {"fillColor": "orange"})
    folium.Popup(f"{r['name']}: {r['num_lockers']}").add_to(geo_j)
    geo_j.add_to(map)

# %% [markdown]
# ## MAP
#
# By clicking on the orange area, name of the estate and the number of parcel lockers will be displayed.

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7669165a9345c30719a823736ae2bf4c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7669165a9345c30719a823736ae2bf4c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7669165a9345c30719a823736ae2bf4c = L.map(
#                 &quot;map_7669165a9345c30719a823736ae2bf4c&quot;,
#                 {
#                     center: [52.4, 16.9],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_05da10d630b1356235125f78563030b7 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_05da10d630b1356235125f78563030b7.addTo(map_7669165a9345c30719a823736ae2bf4c);
#
#
#             var marker_dacf836215e511e2d794e79335436421 = L.marker(
#                 [52.39036, 17.00623],
#                 {}
#             ).addTo(map_7669165a9345c30719a823736ae2bf4c);
#
#
#             var marker_215644e4e9a1e072bc867f68fa804779 = L.marker(
#                 [52.40554, 17.02273],
#                 {}
#             ).addTo(map_7669165a9345c30719a823736ae2bf4c);
#
#
#             var marker_6ba35741956a5f2d7824c231e823407a = L.marker(
#                 [52.40562, 17.01598],
#                 {}
#             ).addTo(map_7669165a9345c30719a823736ae2bf4c);
#
#
#             var marker_97c2c62c51053a44519d04b31b3dbcbe = L.marker(
#                 [52.40776, 17.02434],
#                 {}
#             ).addTo(map_7669165a9345c30719a823736ae2bf4c);
#
#
#             var marker_1f1505d3bcc3da5ec163a8035fe4faf0 = L.marker(
#                 [52.38794, 17.00318],
#                 {}
#             ).addTo(map_7669165a9345c30719a823736ae2bf4c);
#
#
#             var marker_f1a4bb37cb20187b9872c56ff5777383 = L.marker(
#                 [52.40782, 17.01076],
#                 {}
#             ).addTo(map_7669165a9345c30719a823736ae2bf4c);
#
#
#             var marker_73532da6deb74b9b57b69ea6e0411718 = L.marker(
#                 [52.4161, 17.04195],
#                 {}
#             ).addTo(map_7669165a9345c30719a823736ae2bf4c);
#
#
#             var marker_049c1c933fb7def35c706cb9f0fff66c = L.marker(
#                 [52.39302, 16.99397],
#                 {}
#             ).addTo(map_7669165a9345c30719a823736ae2bf4c);
#
#
#             var marker_90f21b8d0af639980565efdf9f8dd39e = L.marker(
#                 [52.39374, 16.99138],
#                 {}
#             ).addTo(map_7669165a9345c30719a823736ae2bf4c);
#
#
#             var marker_e4e99a74455076c87e01ba05956a14a9 = L.marker(
#                 [52.39127, 16.98695],
#                 {}
#             ).addTo(map_7669165a9345c30719a823736ae2bf4c);
#
#
#             var marker_b95754c677c4f15fdf032d9260c6940e = L.marker(
#                 [52.39308, 16.98392],
#                 {}
#             ).addTo(map_7669165a9345c30719a823736ae2bf4c);
#
#
#             var marker_57365b5ebcd10c62c931aa6e501a78f3 = L.marker(
#                 [52.3879, 16.98412],
#                 {}
#             ).addTo(map_7669165a9345c30719a823736ae2bf4c);
#
#
#             var marker_d3548b1e5c860b4ed8d6b3fb443115de = L.marker(
#                 [52.38662, 16.98295],
#                 {}
#             ).addTo(map_7669165a9345c30719a823736ae2bf4c);
#
#
#             var marker_c6a86ba2352652fdcefe35b2c9f888b5 = L.marker(
#                 [52.39171, 16.98113],
#                 {}
#             ).addTo(map_7669165a9345c30719a823736ae2bf4c);
#
#
#             var marker

#                             OrderedDict([('name', 'GeoJson'),
#                                          ('id',
#                                           'bff3f50a1a78bd5fc332d1b857e12cf6'),
#                                          ('children',
#                                           OrderedDict([('popup_53cb1970a4dce5343e9a916c8e7a9a9b',
#                                                         OrderedDict([('name',
#                                                                       'Popup'),
#                                                                      ('id',
#                                                                       '53cb1970a4dce5343e9a916c8e7a9a9b'),
#                                                                      ('children',
#                                                                       OrderedDict())])),
#                                                        ('geo_json_bff3f50a1a78bd5fc332d1b857e12cf6_add',
#                                                         OrderedDict([('name',
#                                                                       'MacroElement'),
#                                                                      ('id',
#                                                                       '7b124af0cb2d66786fc3923171727cb7'),
#                                                                      ('children',
#                                                                       OrderedDict())]))]))])),
#                            ('geo_json_309fe1e9f98c74f78c8f69d474c173d1',
#                             OrderedDict([('name', 'GeoJson'),
#                                          ('id',
#                                           '309fe1e9f98c74f78c8f69d474c173d1'),
#                                          ('children',
#                                           OrderedDict([('popup_15fd50d5de436989b7373362330eaa6a',
#                                                         OrderedDict([('name',
#                                                                       'Popup'),
#                                                                      ('id',
#                                                                       '15fd50d5de436989b7373362330eaa6a'),
#                                                                      ('children',
#                                                                       OrderedDict())])),
#                                                        ('geo_json_309fe1e9f98c74f78c8f69d474c173d1_add',
#                                                         OrderedDict([('name',
#                                                                       'MacroElement'),
#                                                                      ('id',
#                                                                       '7d5ded05a086b746849c7088dd55178c'),
#                                                                      ('children',
#                                                                       OrderedDict())]))]))])),
#                            ('geo_json_0ae924a1d2c0c90fd6c52a3b85723858',
#                             OrderedDict([('name', 'GeoJson'),
#                                          ('id',
#                                           '0ae924a1d2c0c90fd6c52a3b85723858'),
#                                          ('children',
#                                           OrderedDict([('popup_f5d92c494c84f8120f9791ab6d3d0fe6',
#                                                         OrderedDict([('name',
#                                                                       'Popup'),
#                                                                      ('id',
#                                                                       'f5d92c494c84f8120f9791ab6d3d0fe6'),
#                                                                      ('children',
#                                                                       OrderedDict())])),
#                                                        ('geo_json_0ae924a1d2c0c90fd6c52a3b85723858_add',
#                                                         OrderedDict([('name',
#                                                                       'MacroElement'),
#                                                                      ('id',
#                                                                       '1209babcdfa68ef22214daed322f0f02'),
#                                                                      ('children',
#                                                                       OrderedDict())]))]))])),
#                            ('geo_json_1dbc8ab0cbcf8f32092b035fe9267682',
#                             OrderedDict([('name', 'GeoJson'),
#                                          ('id',
#                                           '1dbc8ab0cbcf8f32092b035fe9267682'),
#                                          ('children',
#                                           OrderedDict([('popup_d184d98268db04a1a57e2e38a3423d12',
#                                                         OrderedDict([('name',
#                                                                       'Popup'),
#                                                                      ('id',
#                                                                       'd184d98268db04a1a57e2e38a3423d12'),
#                                                                      ('children',
#                                                                       OrderedDict())])),
#                                                        ('geo_json_1dbc8ab0cbcf8f32092b035fe9267682_add',
#                                                         OrderedDict([('name',
#                                                                       'MacroElement'),
#                                                                      ('id',
#                                                                       '77dd55adbe5926cde44edce2422ee716'),
#                                                                      ('children',
#                                                                       OrderedDict())]))]))])),
#                            ('geo_json_1447d064a3917318ff560fb05e2e9ebe',
#                             OrderedDict([('name', 'GeoJson'),
#                                          ('id',
#                                           '1447d064a3917318ff560fb05e2e9ebe'),
#                                          ('children',
#                                           OrderedDict([('popup_6eb5f73e04177c09fe568340b00ade13',
#                                                         OrderedDict([('name',
#                                                                       'Popup'),
#                                                                      ('id',
#                                                                       '6eb5f73e04177c09fe568340b00ade13'),
#                                                                      ('children',
#                                                                       OrderedDict())])),
#                                                        ('geo_json_1447d064a3917318ff560fb05e2e9ebe_add',
#                                                         OrderedDict([('name',
#                                                                       'MacroElement'),
#                                                                      ('id',
#                                                                       '760eb0813d6ce0b5edbe42915a1441eb'),
#                                                                      ('children',
#                                                                       OrderedDict())]))]))])),
#                            ('geo_json_a7880470068ae70f0c04ec546c8c1ed4',
#                             OrderedDict([('name', 'GeoJson'),
#                                          ('id',
#                                           'a7880470068ae70f0c04ec546c8c1ed4'),
#                                          ('children',
#                                           OrderedDict([('popup_96531e8bc29a035147d5b02a5c872a86',
#                                                         OrderedDict([('name',
#                                                                       'Popup'),
#                                                                      ('id',
#                                                                       '96531e8bc29a035147d5b02a5c872a86'),
#                                                                      ('children',
#                                                                       OrderedDict())])),
#                                                        ('geo_json_a7880470068ae70f0c04ec546c8c1ed4_add',
#                                                         OrderedDict([('name',
#                                                                       'MacroElement'),
#                                                                      ('id',
#                                                                       'bd5d93e0e750618efe8234ef2189b850'),
#                                                                      ('children',
#                                                                       OrderedDict())]))]))]))]))])

# %%
combined = pd.merge(left=estates, right=residents, how='left', left_on='name', right_on='Nazwa osiedla').drop('Nazwa osiedla', axis=1)

combined['res_per_locker'] = combined['Liczba mieszkańców*'] / combined['num_lockers']

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(rc={'figure.figsize':(16,8)})

res_per_locker_map = combined.plot(column='res_per_locker', legend=True, cmap='inferno')
res_per_locker_map.set_axis_off()
res_per_locker_map.set_title('Number of residents per locker')
# Out:
# Text(0.5, 1.0, 'Number of residents per locker')

# %%
sns.barplot(combined, y='name', x='res_per_locker').set(title="Number of residents per locker")
# Out:
# [Text(0.5, 1.0, 'Number of residents per locker')]

# %%
print("Estates with high number of residents per locker: ")
combined[combined['res_per_locker'] > 2000]['name']
# Out:
# Estates with high number of residents per locker:
# 4            Głuszyna
# 8     Piątkowo Północ
# 27       Stare Miasto
# 31          Strzeszyn
# Name: name, dtype: object

# %%
sns.barplot(combined, y='name', x='num_lockers').set(title="Number of lockers in particular estates")
# Out:
# [Text(0.5, 1.0, 'Number of lockers in particular estates')]

# %%
poznan_parcel_lockers = None
for id, row in estates.iterrows():
    poznan_parcel_lockers = pd.concat([poznan_parcel_lockers, parcel_lockers[lockers_in_estates.iloc[id]]], axis=0)

# %%
import re
grocery_store_cond = poznan_parcel_lockers['description'].str.contains(r'([mM]ark|[sS]kle|[Ll]id|[Pp]olsk|[Nn]ett)', regex=True)
parking_cond = poznan_parcel_lockers['description'].str.contains(r'([pP]arking)', regex=True)
building_cond = poznan_parcel_lockers['description'].str.contains(r'([Bb]udy)', regex=True)
petrol_station_cond = poznan_parcel_lockers['description'].str.contains(r'([Ss]tac)', regex=True)
mansion_cond = poznan_parcel_lockers['description'].str.contains(r'([Pp]ose|[Bb]lok)', regex=True)

grocery_store = poznan_parcel_lockers[grocery_store_cond]['description'].shape[0]
parking = poznan_parcel_lockers[ ~grocery_store_cond & parking_cond]['description'].shape[0]
building = poznan_parcel_lockers[ ~grocery_store_cond & ~parking_cond & building_cond]['description'].shape[0]
petrol_station = poznan_parcel_lockers[ ~grocery_store_cond & ~building_cond & petrol_station_cond]['description'].shape[0]
mansion = poznan_parcel_lockers[ ~grocery_store_cond & ~building_cond & ~petrol_station_cond & ~parking_cond & mansion_cond].shape[0]

common_locations = pd.DataFrame({
    "Grocery store": [grocery_store],
    "Parking": [parking],
    "Petrol Station": [petrol_station],
    "Mansion": [mansion],
    "Other": [poznan_parcel_lockers[~grocery_store_cond & ~building_cond & ~petrol_station_cond & ~parking_cond & ~mansion_cond].shape[0]]
})
# Out:
# C:\Users\Hubert\AppData\Local\Temp\ipykernel_15052\1689251452.py:2: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   grocery_store_cond = poznan_parcel_lockers['description'].str.contains(r'([mM]ark|[sS]kle|[Ll]id|[Pp]olsk|[Nn]ett)', regex=True)
# C:\Users\Hubert\AppData\Local\Temp\ipykernel_15052\1689251452.py:3: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   parking_cond = poznan_parcel_lockers['description'].str.contains(r'([pP]arking)', regex=True)
# C:\Users\Hubert\AppData\Local\Temp\ipykernel_15052\1689251452.py:4: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   building_cond = poznan_parcel_lockers['description'].str.contains(r'([Bb]udy)', regex=True)
# C:\Users\Hubert\AppData\Local\Temp\ipykernel_15052\1689251452.py:5: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   petrol_station_cond = poznan_parcel_lockers['description'].str.contains(r'([Ss]tac)', regex=True)
# C:\Users\Hubert\AppData\Local\Temp\ipykernel_15052\1689251452.py:6: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mansion_cond = poznan_parcel_lockers['description'].str.contains(r'([Pp]ose|[Bb]lok)', regex=True)

# %%
common_plot = sns.barplot(common_locations)
common_plot.set(title='Common locations of parcel lockers')

for container in common_plot.containers:
    common_plot.bar_label(container)

# %% [markdown]
# ## Conclusions and further analysis
#
# We can see some interesting trends:
#  - `res_per_locker` is usually less than **2000**, this may mean that estates with this metric above 2000 should have more parcel lockers than currently or that the demand for parcel lockers is lower there
#  - the most common locations of parcel lockers is near grocery stores, so it may mean that customers usually prefer that location
#
#
# To explore these trends more and see if they are true, more data like:
#  - location of customers' orders
#  - amount of orders (prefarable timeline is around the holidays like: christmas to see the greatest usage of parcel lockers is particular area)
#  - to estimate new locations of parcel lockers, some computer vision models would be useful to predict the area of buildings, so the estimation of the location for new parcel locker would not be for example in the middle of the lake
